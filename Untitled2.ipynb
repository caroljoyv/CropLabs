# %%
import pandas as pd

# %%
coding = pd.read_csv("coding_17_features.csv")

# %%
len(coding)
# Out:
# 111275

# %%
coding.head()
# Out:
#    Fickett Score   NucleiA   NucleiG   NucleiT   NucleiC  GC content  \
# 0        0.37617  0.321238  0.175707  0.319328  0.183728    0.359435
# 1        0.46720  0.209798  0.202343  0.330138  0.257721    0.460064
# 2        0.46720  0.209798  0.202343  0.330138  0.257721    0.460064
# 3        0.41608  0.161616  0.341703  0.139105  0.357576    0.699278
# 4        0.41608  0.161765  0.341696  0.138985  0.357555    0.699250
#
#    ORF Length  Relative Codon Bias  Isoelectric Potential  Aromaticity  \
# 0         981             0.284229               9.588915     0.112385
# 1         939             0.460470               9.042610     0.137821
# 2         939             0.460470               9.042610     0.137821
# 3        2535             0.270346              11.870000     0.051948
# 4        2538             0.271500              11.870000     0.051903
#
#    Transcript Length  CpG Islands       SCF           MW     Gravy  \
# ...

# %%
coding.head(10)
# Out:
#    Fickett Score   NucleiA   NucleiG   NucleiT   NucleiC  GC content  \
# 0        0.37617  0.321238  0.175707  0.319328  0.183728    0.359435
# 1        0.46720  0.209798  0.202343  0.330138  0.257721    0.460064
# 2        0.46720  0.209798  0.202343  0.330138  0.257721    0.460064
# 3        0.41608  0.161616  0.341703  0.139105  0.357576    0.699278
# 4        0.41608  0.161765  0.341696  0.138985  0.357555    0.699250
# 5        0.40843  0.201550  0.320413  0.155039  0.322997    0.643411
# 6        0.42995  0.181854  0.326163  0.150567  0.341416    0.667579
# 7        0.40599  0.173635  0.332753  0.141696  0.351916    0.684669
# 8        0.40017  0.166667  0.332258  0.143011  0.358065    0.690323
# 9        0.41928  0.166423  0.327965  0.142997  0.362616    0.690581
#
#    ORF Length  Relative Codon Bias  Isoelectric Potential  Aromaticity  \
# 0         981             0.284229               9.588915     0.112385
# ...
